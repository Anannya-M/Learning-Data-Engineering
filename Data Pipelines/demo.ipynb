# %%
from googleapiclient.discovery import build
import os
import json
import pandas as pd
# Out:
# C:\Users\anann\AppData\Local\Temp\ipykernel_20912\1898033269.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
API_KEY = 'AIzaSyBPBYiwuOb23cFoP_FTGF_YOturSWsANEc'

# %%
youtube = build('youtube','v3',developerKey = API_KEY)

request = youtube.commentThreads().list(
            part="snippet, replies",
            videoId="j58-XvdR62E"
        )

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Xj_J6SWqF56hMvAFnri0zUd_CEc',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpb0lCZ0FFZ1VJaVNBWUFCSUZDSWNnR0FBU0JRaWRJQmdCR0FBaURnb01DUHZiOEs0R0VKRHpxTEVC',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '9AO1b_2AISnVFwQWA2txdcKPrWE',
#    'id': 'UgxQvwkJ72UDiDBpV0d4AaABAg',
#    'snippet': {'channelId': 'UCm8EZfto3AdXqklkb2k550w',
#     'videoId': 'j58-XvdR62E',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M1F3MKUM3reuR9fAXJorLA88TCQ',
#      'id': 'UgxQvwkJ72UDiDBpV0d4AaABAg',
#      'snippet': {'channelId': 'UCm8EZfto3AdXqklkb2k550w',
#       'videoId': 'j58-XvdR62E',
# ...

# %%
response
# Out:
# 5

# %%
response['items'][3]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# {'channelId': 'UCm8EZfto3AdXqklkb2k550w',
#  'videoId': 'j58-XvdR62E',
#  'textDisplay': 'Health is sick your ok',
#  'textOriginal': 'Health is sick your ok',
#  'authorDisplayName': '@lllRevalll',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m7KJ4h2NAdOLQuIBWXDlb4fVEhVrmXM6NyAnFa=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/@lllRevalll',
#  'authorChannelId': {'value': 'UCDvRdM_z_rSVWeMhTB12w6Q'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 0,
#  'publishedAt': '2024-02-27T16:42:01Z',
#  'updatedAt': '2024-02-27T16:42:01Z'}

# %%
data_info = []
for info_items in response:
    comments = info_items['items'][3]['snippet']['topLevelComment']['snippet']['textOriginal']
    author = info_items['items'][3]['snippet']['topLevelComment']['snippet']['authorDisplayName']
    timestamp = info_items['items'][3]['snippet']['topLevelComment']['snippet']['publishedAt']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 data_info = []
#       2 for info_items in response:
# ----> 3     comments = info_items['items'][3]['snippet']['topLevelComment']['snippet']['textOriginal']
#       4     author = info_items['items'][3]['snippet']['topLevelComment']['snippet']['authorDisplayName']
#       5     timestamp = info_items['items'][3]['snippet']['topLevelComment']['snippet']['publishedAt']
#
# TypeError: string indices must be integers, not 'str'

# %%
data_info = []

for info_item in response.get('items', []):
    # Check if 'snippet' exists in the current item
    snippet = info_item.get('snippet', {})
    
    # Accessing topLevelComment within snippet
    top_level_comment = snippet.get('topLevelComment', {})
    
    # Accessing snippet within topLevelComment
    comment_snippet = top_level_comment.get('snippet', {})
    
    # Extracting desired information
    comments = comment_snippet.get('textOriginal', '')
    author = comment_snippet.get('authorDisplayName', '')
    timestamp = comment_snippet.get('publishedAt', '')
    
    # Creating a dictionary to store the information
    data_info.append({'Comments': comments, 'Author': author, 'Timestamp': timestamp})

# Printing or using the extracted data
# for data in data_info:
#     print(data)

# %%
data_df = pd.DataFrame(data_info)
data_df
# Out:
#                                              Comments  \
# 0   I've been very sick for the last 1-2 weeks so ...
# 1        Bhai Himalayan YETI KE BAARE ME VIDEO BANAYE
# 2   I am literally sorry for Fing. He is the most ...
# 3                              Health is sick your ok
# 4   Thanks brother, for exposing these Americans. ...
# 5                    Jua sikha khelna logo ko shabash
# 6                    Indian conspiracy theories when?
# 7                     Finggg Bhai 26/11 pe video bana
# 8   5:22 bhai sach mai hansi aagai tbh😂😂\nIts like...
# 9   Editing and production in fing's normal video:...
# 10              Baki sab to thik h par intro formal h
# 11  brother to be honest this attack was very unfo...
# 12  conspiracy yeh bhi kehti hai ki fing bhai bhi ...
# 13                          plz also make on pyramids
# 14  Yani main sabse bekaar din paida hua hoon 11 s...
# 15  I think Fing got kidnapped after exposing ther...
# ...

# %%
# Assuming 'response' is your dictionary containing comment thread information
data_info = [
    {
        'comments': item['snippet']['topLevelComment']['snippet']['textOriginal'],
        'author': item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
        'timestamp': item['snippet']['topLevelComment']['snippet']['publishedAt']
    }
    for item in response.get('items', [])
]

# Printing or using the extracted data
for data in data_info:
    print(data)
# Out:
# {'comments': "I've been very sick for the last 1-2 weeks so my voice might have sounded different in the last two episodes, but still, I'm trying my best to entertain you guys. Thanks for all the love and support on this series.", 'author': '@FING.', 'timestamp': '2024-02-12T13:38:58Z'}
# {'comments': 'Bhai Himalayan YETI KE BAARE ME VIDEO BANAYE', 'author': '@malwafoodhavenspecial2687', 'timestamp': '2024-02-27T22:35:28Z'}
# {'comments': 'I am literally sorry for Fing. He is the most underrated Indian  YouTuber. 😢', 'author': '@imranbinhossain6942', 'timestamp': '2024-02-27T17:22:44Z'}
# {'comments': 'Health is sick your ok', 'author': '@lllRevalll', 'timestamp': '2024-02-27T16:42:01Z'}
# {'comments': 'Thanks brother, for exposing these Americans. Because they always said that this was a terrorist attack planted by Muslims.', 'author': '@amarulhaq3844', 'timestamp': '2024-02-27T13:18:07Z'}
# ...

# %%
len(response)
